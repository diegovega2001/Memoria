# %%
import os

os.chdir(os.path.expanduser("~/Memoria"))

# %%
import torch
import gc

def clean_cuda():
    gc.collect()
    torch.cuda.empty_cache()

# %%
clean_cuda()

# %%
import pandas as pd
dataset_df = pd.read_csv('dataset.csv')

# %%
from src.pipeline.VisionPipeline import VisionPipeline

# %%
import json

with open('ViTBase16/configurations.json', 'r') as file:
    configurations = json.load(file)

# %%
def create_run_save_destroy_experiment(idx, configurations=configurations):
    pipeline = VisionPipeline(configurations[idx], dataset_df)
    pipeline.run_full_pipeline(include_finetune=True)
    pipeline.save_results(configurations[idx]["name"])
    clean_cuda()

# %% [markdown]
# Front View

# %%
create_run_save_destroy_experiment(0)
# Out:
# INFO:root:=== RUNNING BASELINE ===
# INFO:root:=== Dataset Overview ===
# Views: ['front']
# Number of models: 1184
# Train images per model per view: 5
# Val ratio = 0.75, Test ratio = 0.25
# Total validation images: 8160
# Validation images per model per view: Mean 6.891891891891892, Std: 4.786326435280966
# Total test images: 3294
# Test images per model per view: Mean 2.7820945945945947, Std: 1.6449606720750147
#
# INFO:root: === Model vit_b_16 created on cuda ===
# INFO:root: === Baseline embeddings extracted: torch.Size([3294, 768]) ===
# INFO:root:Initialized with 3294 samples, 768 features
# INFO:root:Using 15 CPU cores
# INFO:root:Processing PCA...
# [I 2025-09-10 19:20:14,230] A new study created in memory with name: no-name-7f5ec7a9-6df0-4a21-9a7c-9face02f2e9d
#   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:root:Optimization completed for pca. Best value: 0.1844
# INFO:root:Best params for pca: {'n_components': 231}
# ...

# %%
create_run_save_destroy_experiment(1)

# %%
create_run_save_destroy_experiment(2)

# %% [markdown]
# Front and Rear View

# %%
create_run_save_destroy_experiment(3)

# %%
create_run_save_destroy_experiment(4)

# %%
create_run_save_destroy_experiment(5)

# %% [markdown]
# Grayscale

# %%
create_run_save_destroy_experiment(6)

# %%
create_run_save_destroy_experiment(7)
